# %% [markdown]
# # Script Intro
# This Python code retrieves drug information from the openFDA API based on provided keywords, processes the data, and writes it to an Excel file.
#
# If "No data found for keyword: KEYWORD" is returned, check to ensure that either a name_brand or generic_name of that is included in the keyword list.  If the generic_name or the name_brand are included, it is confidently covered.  Otherwise, if neither the name_brand or generic_name are found, it is recommended to add that name to the keywords list and run the script again.
#
# Before using this script, you must have an APIKey with openFDA.  [Go here to get an openFDA apiKey](https://open.fda.gov/apis/authentication/)
#
# ## Notes and Limitations
# - openFDA has a limited call per keyword of 1000 items returned.  While this limit should not cause an issue with our calls, the possibility is factored into this code.  If you receive a "Warning: Total results for {keyword} exceed the specified limit" message after running Step 3 of this script, please contact me at alyssa.warnock@amida.com or over slack and I will do my best to help troubleshoot this issue.
# - If you do not change the Excel_Sheet_Name variable and attempt to run the code again with a different string_list keywords list, the code will overwrite your existing file with the new string_list variables.
#
# ## Common Errors
# - No current common errors have been reported.  If you encounter an error with this script, please contact me at alyssa.warnock@amida.com or over slack and I will do my best to troubleshoot any issues with the code.
#
# ## Steps to Use:

# %% [markdown]
# ## Step 1: Run Imports

# %%
import requests 
import pandas as pd

# %% [markdown]
# ## Step 2: Provide Required Inputs
#
# #### Required Inputs
# - apikey
#     - This is an openFDA apiKey.  It is required to run this script.
#     - [Go here to get an openFDA apiKey](https://open.fda.gov/apis/authentication/)
#     - Example apikey: '48rTW74aYgis4NSRknDQGbcXtjqv5nwse24USh'
# - Excel_Sheet_Name
#     - This is the title of the outputted excel sheet.
#     - Outputs each code into two columns: "NDC" and "DrugNameWithDose"
# - string_list
#     - This is the list of keywords you want the script to query for NDC codes.
#     - This must be inputted as either a list of strings or an excel file
#     - See "string_list Keywords" section for more details

# %%
apikey = 'YOUR API KEY HERE'
Excel_Sheet_Name = "EXCEL SHEET NAME HERE"

# %% [markdown]
# ## string_list Keywords
# Only run **one** of these three chunks below:
#
# #### A. Manually Provide Keywords List
# - Run this chunk if you have a short list of keywords that you want to manually input and run a query.
#
# #### B. Excel Keywords List, Excludes Column Name in Keyword Search
# - Run this chunk if you have a longer list of keywords that are formatted in an Excel document **with** dedicated column titles.  This chunk will **exclude** the column title **from** the keyword search.
#
# #### C. Excel Keywords List, Includes Column Name in Keyword Search
# - Run this chunk if you have a longer list of keywords that are formatted in an Excel document without dedicated column titles.  This chunk will **include** the column title **in** the keyword search.

# %% [markdown]
# ### A. Manually Provide Keywords List

# %%
#Edit this list 
keywords_list = ["Tipiracil hydrochloride", "Keyword 2", "Keyword 3"]

keywords_list = [keyword.replace(' ', '+') for keyword in keywords_list]
modified_list = ['"' + word + '"' for word in keywords_list]
string_list = modified_list

print(string_list)
# Out:
# ['"Tipiracil+hydrochloride"']

# %% [markdown]
# ### B. Excel Keywords List, Excludes Column Name in Keyword Search
# Additional Steps:
#  1. Modify the "df" variable path to reflect the path to your personal keywords excel sheet
#  2. Modfiy the "column_name" variable to reflect the name of the column you want to pull keywords from in your personal keywords excel sheet.

# %%
# Modify this path to your excel document with the keywords you want the script to pull NDC codes for
df = pd.read_excel('C:/Users/Alyssa/OneDrive - Amida/Desktop/Python/openFDA API Pulls/GI Cancer Med Keywords.xlsx')

# Assuming df is your DataFrame and 'column_name' is the name of the column you want to convert to a list
column_name = 'Keywords'

# Extract the column as a Pandas Series
column_series = df[column_name]

# Convert the Pandas Series to a list and include the column name as the first element
column_list = [keyword.replace(' ', '+') for keyword in column_series.tolist()]
modified_list = ['"' + word + '"' for word in column_list]
string_list = modified_list

# Now column_list contains the column data with the column name as the first element
print(string_list)
# Out:
# ['"Aflibercept"', '"Eylea"', '"Zaltrap"', '"ziv-aflibercept"', '"Atezolizumab"', '"Tecentriq"', '"Alymsys"', '"Avastin"', '"Bevacizumab"', '"bevacizumab-awwb"', '"bevacizumab-bvzr"', '"bevacizumab-maly"', '"Mvasi"', '"Zirabev"', '"Cabometyx"', '"cabozantinib"', '"Cometriq"', '"Capecitabine"', '"Xeloda"', '"carboplatin"', '"Paraplatin"', '"cetuximab"', '"Erbitux"', '"cisplatin"', '"cyclophosphamide"', '"Docefrez"', '"Docetaxel"', '"Taxotere"', '"Adriamycin"', '"Doxil"', '"Doxorubicin"', '"doxorubicin+hydrochloride"', '"doxorubicin+hydrochloride+liposome"', '"LipoDox"', '"Braftovi"', '"encorafenib"', '"entrectinib"', '"Rozlytrek"', '"Ellence"', '"epirubicin"', '"epirubicin+hydrochloride"', '"gemcitabine"', '"Infugem"', '"Ipilimumab"', '"Yervoy"', '"Camptosar"', '"Irinotecan"', '"Irinotecan+hydrochloride"', '"Irinotecan+hydrochloride+liposome"', '"Onivyde"', '"larotrectinib"', '"larotrectinib+sulfate"', '"Vitrakvi"', '"lenvatinib"', '"lenvatinib+mesylate"', '"Lenvima"', '"leucovorin"', '"leucovorin+calcium"', '"Fusilev"', '"Khapzory"', '"levoleucovorin"', '"levoleucovorin+calcium"', '"levoleucovorin+calcium"', '"levoleucovorin+disodium"', '"Jelmyto"', '"Mitomycin"', '"Mitosol"', '"Mutamycin"', '"mitoxantrone"', '"mitoxantrone+hydrochloride"', '"Nivolumab"', '"Nivolumab+relatlimab"', '"Nivolumab-RMBW"', '"Opdivo"', '"Opdualag"', '"Relatlimab"', '"Relatlimab-rmbw"', '"Oxaliplatin"', '"Abraxane"', '"Paclitaxel"', '"panitumumab"', '"Vectibix"', '"Keytruda"', '"Pembrolizumab"', '"Cyramza"', '"ramucirumab"', '"regorafenib"', '"regorafenib+monohydrate"', '"Stivarga"', '"Nexavar"', '"sorafenib"', '"sorafenib+tosylate"', '"Lonsurf"', '"Tipiracil"', '"Tipiracil+hydrochloride"', '"Tipiracil+trifluridine"', '"trifluridine"', '"ado-trastuzumab"', '"ado-trastuzumab+emtansine"', '"Enhertu"', '"fam-trastuzumab+deruxtecan-nxki"', '"Herceptin"', '"Herceptin+Hylecta"', '"Herzuma"', '"hyaluronidase+"', '"hyaluronidase+trastuzumab"', '"Kadcyla"', '"Kanjinti"', '"Ogivri"', '"Ontruzant"', '"pertuzumab"', '"Phesgo"', '"T-DM1"', '"trastuzumab"', '"trastuzumab+deruxtecan"', '"trastuzumab+emtansine"', '"trastuzumab-anns"', '"trastuzumab-dkst"', '"trastuzumab-DM1"', '"trastuzumab-dttb"', '"trastuzumab-oysk"', '"trastuzumab-pkrb"', '"trastuzumab-qyyp"', '"trastuzumab-zzxf"', '"Trazimera"', '"vindesine"']

# %% [markdown]
# ### C. Excel Keywords List, Includes Column Name in Keyword Search
# Additional Steps:
#  1. Modify the "df" variable path to reflect the path to your personal keywords excel sheet
#  2. Modfiy the "column_name" variable to reflect the name of the column you want to pull keywords from in your personal keywords excel sheet.

# %%
# Modify this path to your excel document with the keywords you want the script to pull NDC codes for
df = pd.read_excel('C:/Users/Alyssa/OneDrive - Amida/Desktop/Python/openFDA API Pulls/GI Cancer Med Keywords.xlsx')

# Assuming df is your DataFrame and 'column_name' is the name of the column you want to convert to a list
column_name = 'Keywords'

# Extract the column as a Pandas Series
column_series = df[column_name]

# Convert the Pandas Series to a list and include the column name as the first element
column_list = [keyword.replace(' ', '+') for keyword in [column_name]] + [keyword.replace(' ', '+') for keyword in column_series.tolist()]
modified_list = ['"' + word + '"' for word in column_list]
string_list = modified_list

# Now column_list contains the column data with the column name as the first element
print(string_list)
# Out:
# ['"Keywords"', '"Aflibercept"', '"Eylea"', '"Zaltrap"', '"ziv-aflibercept"', '"Atezolizumab"', '"Tecentriq"', '"Alymsys"', '"Avastin"', '"Bevacizumab"', '"bevacizumab-awwb"', '"bevacizumab-bvzr"', '"bevacizumab-maly"', '"Mvasi"', '"Zirabev"', '"Cabometyx"', '"cabozantinib"', '"Cometriq"', '"Capecitabine"', '"Xeloda"', '"carboplatin"', '"Paraplatin"', '"cetuximab"', '"Erbitux"', '"cisplatin"', '"cyclophosphamide"', '"Docefrez"', '"Docetaxel"', '"Taxotere"', '"Adriamycin"', '"Doxil"', '"Doxorubicin"', '"doxorubicin+hydrochloride"', '"doxorubicin+hydrochloride+liposome"', '"LipoDox"', '"Braftovi"', '"encorafenib"', '"entrectinib"', '"Rozlytrek"', '"Ellence"', '"epirubicin"', '"epirubicin+hydrochloride"', '"gemcitabine"', '"Infugem"', '"Ipilimumab"', '"Yervoy"', '"Camptosar"', '"Irinotecan"', '"Irinotecan+hydrochloride"', '"Irinotecan+hydrochloride+liposome"', '"Onivyde"', '"larotrectinib"', '"larotrectinib+sulfate"', '"Vitrakvi"', '"lenvatinib"', '"lenvatinib+mesylate"', '"Lenvima"', '"leucovorin"', '"leucovorin+calcium"', '"Fusilev"', '"Khapzory"', '"levoleucovorin"', '"levoleucovorin+calcium"', '"levoleucovorin+calcium"', '"levoleucovorin+disodium"', '"Jelmyto"', '"Mitomycin"', '"Mitosol"', '"Mutamycin"', '"mitoxantrone"', '"mitoxantrone+hydrochloride"', '"Nivolumab"', '"Nivolumab+relatlimab"', '"Nivolumab-RMBW"', '"Opdivo"', '"Opdualag"', '"Relatlimab"', '"Relatlimab-rmbw"', '"Oxaliplatin"', '"Abraxane"', '"Paclitaxel"', '"panitumumab"', '"Vectibix"', '"Keytruda"', '"Pembrolizumab"', '"Cyramza"', '"ramucirumab"', '"regorafenib"', '"regorafenib+monohydrate"', '"Stivarga"', '"Nexavar"', '"sorafenib"', '"sorafenib+tosylate"', '"Lonsurf"', '"Tipiracil"', '"Tipiracil+hydrochloride"', '"Tipiracil+trifluridine"', '"trifluridine"', '"ado-trastuzumab"', '"ado-trastuzumab+emtansine"', '"Enhertu"', '"fam-trastuzumab+deruxtecan-nxki"', '"Herceptin"', '"Herceptin+Hylecta"', '"Herzuma"', '"hyaluronidase+"', '"hyaluronidase+trastuzumab"', '"Kadcyla"', '"Kanjinti"', '"Ogivri"', '"Ontruzant"', '"pertuzumab"', '"Phesgo"', '"T-DM1"', '"trastuzumab"', '"trastuzumab+deruxtecan"', '"trastuzumab+emtansine"', '"trastuzumab-anns"', '"trastuzumab-dkst"', '"trastuzumab-DM1"', '"trastuzumab-dttb"', '"trastuzumab-oysk"', '"trastuzumab-pkrb"', '"trastuzumab-qyyp"', '"trastuzumab-zzxf"', '"Trazimera"', '"vindesine"']

# %% [markdown]
# ## Step 3: Run the Script
#
# ### How does this script work?
# The script is composed of 4 major functions/sections:
#
# 1. **query_openFDA(keyword):**
#    - This function takes a `keyword` as input, which is a drug name.
#    - It constructs a URL to query the openFDA API for drug information based on the `keyword`and makes GET requests to the constructed URLs using the `requests.get()` function.
#    - If the request is successful (status code 200), it parses the JSON response to extract data.
#    - It checks the metadata of the response to ensure the number of results does not exceed the maximum limit of 1000.
#    - If data is found (`data.get("results")`), it returns the results.
#    - If the generic name search fails, it retries with the brand name.
#    - It prints warnings or error messages if there are issues with fetching data.
#
# 2. **process_data(results):**
#    - This function takes the results obtained from querying the openFDA API in the query_openFDA() function as input.
#    - It iterates over each result and extracts relevant information such as generic name, brand name, dosage form, active strength, and package NDC.
#    - It constructs a string `drug_name_with_dose` combining the generic_name (selecting the brand_name if generic_name is not available), active strength, and packaging description.
#    - It appends the package NDC and `drug_name_with_dose` to a list called `records`.
#    - Finally, it returns the `records` list.
#
# 3. **main(keywords):**
#    - This function is the main entry point of the program.
#    - It takes a list of keywords (drug names) as input.
#    - It initializes an empty list called `records`.
#    - It iterates over each keyword, querying the openFDA API using `query_openFDA()` function.
#    - If data is found for a keyword, it processes the data using `process_data()` function and appends the records to the `records` list.
#    - If no data is found for a keyword, it prints a message.
#    - It creates a Pandas DataFrame (`df`) from the `records` list with columns "NDC" and "DrugNameWithDose".  The script drops any NDC duplicates that may have been picked up by querying both a generic_name and brand_name.
#    - It returns the DataFrame.
#
# 4. **Main Execution Block:**
#    - It checks if the script is being run directly (`if __name__ == "__main__":`).
#    - It calls the `main()` function with an example list of keywords (`string_list`).
#    - It writes the DataFrame to an Excel file using `pd.ExcelWriter()` and `to_excel()` functions.

# %%
def query_openFDA(keyword):
    # Query for generic_name
    # Note: Some generics DONT have a brand_name variable
    url_generic = f"https://api.fda.gov/drug/ndc.json?api_key={apikey}&search=generic_name:{keyword}&limit=1000"
    response = requests.get(url_generic)
    
    if response.status_code == 200:
        data = response.json()
        meta = data.get("meta")
        
        if meta:
            total_results = meta.get("results", {}).get("total", 0)
            limit = meta.get("results", {}).get("limit", 1) #check this for the limit
            
            if total_results > limit:
                print(f'Warning: Total results for {keyword} exceed the specified limit.')
            else:
                print(f'Query for generic_name {keyword} successful. \n')
                
        else:
            print(f'Warning: Metadata not found in the response for {keyword}.')
            
        if data.get("results"):
            return data["results"]
    
    else:
        print(f'generic_name: Failed to fetch data from openFDA API for {keyword}.')
    
    # If generic_name search fails, try brand_name
    url_brand = f"https://api.fda.gov/drug/ndc.json?api_key={apikey}&search=brand_name:{keyword}&limit=1000"
    response = requests.get(url_brand)
    
    if response.status_code == 200:
        data = response.json()
        meta = data.get("meta")
        
        if meta:
            total_results = meta.get("results", {}).get("total", 0)
            limit = meta.get("results", {}).get("limit", 1)
            
            if total_results > limit:
                print(f'Warning: Total results for {keyword} exceed the specified limit.')
            else:
                print(f'Query for brand_name {keyword} successful. \n')
                
        else:
            print(f'Warning: Metadata not found in the response for {keyword}.')
            
        if data.get("results"):
            return data["results"]
    else:
        print(f'brand_name: Failed to fetch data from openFDA API for {keyword}.')


def process_data(results):
    records = []
    for result in results:
        generic_name = result.get("generic_name")
        brand_name = result.get("brand_name")
        packaging = result.get("packaging", [])
        strength = result.get("active_ingredients", [{}])[0].get("strength")
        for package in packaging:
            package_ndc = package.get("package_ndc")
            description = package.get("description")
            drug_name_with_dose = (f'{generic_name} ' if generic_name else f'{brand_name} ') + (f'{strength} ' if strength else '') + f'{description}'
            records.append([package_ndc, drug_name_with_dose])
    return records

def main(keywords):
    records = []
    for keyword in keywords:
        results = query_openFDA(keyword)
        if results:
            records += process_data(results)
        else:
            print(f"No data found for keyword: {keyword} \n")
    df = pd.DataFrame(records, columns=["NDC", "DrugNameWithDose"])
    
        # Drop duplicate rows based on the 'NDC' column
    df.drop_duplicates(subset=['NDC'], inplace=True)
    
    return df

if __name__ == "__main__":
    # Example list of keywords
    df = main(string_list)

    # Write DataFrame to an Excel file
    with pd.ExcelWriter(f'{Excel_Sheet_Name}.xlsx') as writer:
        df.to_excel(writer, sheet_name="Sheet1", index=False)
# Out:
# Query for generic_name "Aflibercept" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Eylea".
# Query for brand_name "Eylea" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Zaltrap".
# Query for brand_name "Zaltrap" successful.
#
# Query for generic_name "ziv-aflibercept" successful.
#
# Query for generic_name "Atezolizumab" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Tecentriq".
# Query for brand_name "Tecentriq" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Alymsys".
# Query for brand_name "Alymsys" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Avastin".
# Query for brand_name "Avastin" successful.
#
# Query for generic_name "Bevacizumab" successful.
#
# Query for generic_name "bevacizumab-awwb" successful.
#
# Query for generic_name "bevacizumab-bvzr" successful.
#
# Query for generic_name "bevacizumab-maly" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Mvasi".
# Query for brand_name "Mvasi" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Zirabev".
# Query for brand_name "Zirabev" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Cabometyx".
# Query for brand_name "Cabometyx" successful.
#
# Query for generic_name "cabozantinib" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Cometriq".
# Query for brand_name "Cometriq" successful.
#
# Query for generic_name "Capecitabine" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Xeloda".
# Query for brand_name "Xeloda" successful.
#
# Query for generic_name "carboplatin" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Paraplatin".
# Query for brand_name "Paraplatin" successful.
#
# Query for generic_name "cetuximab" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Erbitux".
# Query for brand_name "Erbitux" successful.
#
# Query for generic_name "cisplatin" successful.
#
# Query for generic_name "cyclophosphamide" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Docefrez".
# brand_name: Failed to fetch data from openFDA API for "Docefrez".
# No data found for keyword: "Docefrez"
#
# Query for generic_name "Docetaxel" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Taxotere".
# brand_name: Failed to fetch data from openFDA API for "Taxotere".
# No data found for keyword: "Taxotere"
#
# generic_name: Failed to fetch data from openFDA API for "Adriamycin".
# Query for brand_name "Adriamycin" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Doxil".
# Query for brand_name "Doxil" successful.
#
# Query for generic_name "Doxorubicin" successful.
#
# Query for generic_name "doxorubicin+hydrochloride" successful.
#
# Query for generic_name "doxorubicin+hydrochloride+liposome" successful.
#
# generic_name: Failed to fetch data from openFDA API for "LipoDox".
# brand_name: Failed to fetch data from openFDA API for "LipoDox".
# No data found for keyword: "LipoDox"
#
# generic_name: Failed to fetch data from openFDA API for "Braftovi".
# Query for brand_name "Braftovi" successful.
#
# Query for generic_name "encorafenib" successful.
#
# Query for generic_name "entrectinib" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Rozlytrek".
# Query for brand_name "Rozlytrek" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Ellence".
# Query for brand_name "Ellence" successful.
#
# Query for generic_name "epirubicin" successful.
#
# Query for generic_name "epirubicin+hydrochloride" successful.
#
# Query for generic_name "gemcitabine" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Infugem".
# brand_name: Failed to fetch data from openFDA API for "Infugem".
# No data found for keyword: "Infugem"
#
# Query for generic_name "Ipilimumab" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Yervoy".
# Query for brand_name "Yervoy" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Camptosar".
# Query for brand_name "Camptosar" successful.
#
# Query for generic_name "Irinotecan" successful.
#
# Query for generic_name "Irinotecan+hydrochloride" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Irinotecan+hydrochloride+liposome".
# brand_name: Failed to fetch data from openFDA API for "Irinotecan+hydrochloride+liposome".
# No data found for keyword: "Irinotecan+hydrochloride+liposome"
#
# generic_name: Failed to fetch data from openFDA API for "Onivyde".
# Query for brand_name "Onivyde" successful.
#
# Query for generic_name "larotrectinib" successful.
#
# Query for generic_name "larotrectinib+sulfate" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Vitrakvi".
# Query for brand_name "Vitrakvi" successful.
#
# Query for generic_name "lenvatinib" successful.
#
# Query for generic_name "lenvatinib+mesylate" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Lenvima".
# Query for brand_name "Lenvima" successful.
#
# Query for generic_name "leucovorin" successful.
#
# Query for generic_name "leucovorin+calcium" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Fusilev".
# Query for brand_name "Fusilev" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Khapzory".
# Query for brand_name "Khapzory" successful.
#
# Query for generic_name "levoleucovorin" successful.
#
# Query for generic_name "levoleucovorin+calcium" successful.
#
# Query for generic_name "levoleucovorin+calcium" successful.
#
# generic_name: Failed to fetch data from openFDA API for "levoleucovorin+disodium".
# brand_name: Failed to fetch data from openFDA API for "levoleucovorin+disodium".
# No data found for keyword: "levoleucovorin+disodium"
#
# generic_name: Failed to fetch data from openFDA API for "Jelmyto".
# Query for brand_name "Jelmyto" successful.
#
# Query for generic_name "Mitomycin" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Mitosol".
# Query for brand_name "Mitosol" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Mutamycin".
# Query for brand_name "Mutamycin" successful.
#
# Query for generic_name "mitoxantrone" successful.
#
# Query for generic_name "mitoxantrone+hydrochloride" successful.
#
# Query for generic_name "Nivolumab" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Nivolumab+relatlimab".
# brand_name: Failed to fetch data from openFDA API for "Nivolumab+relatlimab".
# No data found for keyword: "Nivolumab+relatlimab"
#
# generic_name: Failed to fetch data from openFDA API for "Nivolumab-RMBW".
# brand_name: Failed to fetch data from openFDA API for "Nivolumab-RMBW".
# No data found for keyword: "Nivolumab-RMBW"
#
# generic_name: Failed to fetch data from openFDA API for "Opdivo".
# Query for brand_name "Opdivo" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Opdualag".
# Query for brand_name "Opdualag" successful.
#
# Query for generic_name "Relatlimab" successful.
#
# Query for generic_name "Relatlimab-rmbw" successful.
#
# Query for generic_name "Oxaliplatin" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Abraxane".
# Query for brand_name "Abraxane" successful.
#
# Query for generic_name "Paclitaxel" successful.
#
# Query for generic_name "panitumumab" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Vectibix".
# Query for brand_name "Vectibix" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Keytruda".
# Query for brand_name "Keytruda" successful.
#
# Query for generic_name "Pembrolizumab" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Cyramza".
# Query for brand_name "Cyramza" successful.
#
# Query for generic_name "ramucirumab" successful.
#
# Query for generic_name "regorafenib" successful.
#
# Query for generic_name "regorafenib+monohydrate" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Stivarga".
# Query for brand_name "Stivarga" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Nexavar".
# Query for brand_name "Nexavar" successful.
#
# Query for generic_name "sorafenib" successful.
#
# Query for generic_name "sorafenib+tosylate" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Lonsurf".
# Query for brand_name "Lonsurf" successful.
#
# Query for generic_name "Tipiracil" successful.
#
# Query for generic_name "Tipiracil+hydrochloride" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Tipiracil+trifluridine".
# brand_name: Failed to fetch data from openFDA API for "Tipiracil+trifluridine".
# No data found for keyword: "Tipiracil+trifluridine"
#
# Query for generic_name "trifluridine" successful.
#
# Query for generic_name "ado-trastuzumab" successful.
#
# Query for generic_name "ado-trastuzumab+emtansine" successful.
#
# Query for generic_name "Enhertu" successful.
#
# Query for generic_name "fam-trastuzumab+deruxtecan-nxki" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Herceptin".
# Query for brand_name "Herceptin" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Herceptin+Hylecta".
# Query for brand_name "Herceptin+Hylecta" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Herzuma".
# Query for brand_name "Herzuma" successful.
#
# Query for generic_name "hyaluronidase+" successful.
#
# generic_name: Failed to fetch data from openFDA API for "hyaluronidase+trastuzumab".
# brand_name: Failed to fetch data from openFDA API for "hyaluronidase+trastuzumab".
# No data found for keyword: "hyaluronidase+trastuzumab"
#
# generic_name: Failed to fetch data from openFDA API for "Kadcyla".
# Query for brand_name "Kadcyla" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Kanjinti".
# Query for brand_name "Kanjinti" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Ogivri".
# Query for brand_name "Ogivri" successful.
#
# Query for generic_name "Ontruzant" successful.
#
# Query for generic_name "pertuzumab" successful.
#
# generic_name: Failed to fetch data from openFDA API for "Phesgo".
# Query for brand_name "Phesgo" successful.
#
# generic_name: Failed to fetch data from openFDA API for "T-DM1".
# brand_name: Failed to fetch data from openFDA API for "T-DM1".
# No data found for keyword: "T-DM1"
#
# Query for generic_name "trastuzumab" successful.
#
# Query for generic_name "trastuzumab+deruxtecan" successful.
#
# Query for generic_name "trastuzumab+emtansine" successful.
#
# Query for generic_name "trastuzumab-anns" successful.
#
# Query for generic_name "trastuzumab-dkst" successful.
#
# generic_name: Failed to fetch data from openFDA API for "trastuzumab-DM1".
# brand_name: Failed to fetch data from openFDA API for "trastuzumab-DM1".
# No data found for keyword: "trastuzumab-DM1"
#
# generic_name: Failed to fetch data from openFDA API for "trastuzumab-dttb".
# brand_name: Failed to fetch data from openFDA API for "trastuzumab-dttb".
# No data found for keyword: "trastuzumab-dttb"
#
# generic_name: Failed to fetch data from openFDA API for "trastuzumab-oysk".
# brand_name: Failed to fetch data from openFDA API for "trastuzumab-oysk".
# No data found for keyword: "trastuzumab-oysk"
#
# generic_name: Failed to fetch data from openFDA API for "trastuzumab-pkrb".
# brand_name: Failed to fetch data from openFDA API for "trastuzumab-pkrb".
# No data found for keyword: "trastuzumab-pkrb"
#
# Query for generic_name "trastuzumab-qyyp" successful.
#
# generic_name: Failed to fetch data from openFDA API for "trastuzumab-zzxf".
# brand_name: Failed to fetch data from openFDA API for "trastuzumab-zzxf".
# No data found for keyword: "trastuzumab-zzxf"
#
# generic_name: Failed to fetch data from openFDA API for "Trazimera".
# Query for brand_name "Trazimera" successful.
#
# generic_name: Failed to fetch data from openFDA API for "vindesine".
# brand_name: Failed to fetch data from openFDA API for "vindesine".
# No data found for keyword: "vindesine"
